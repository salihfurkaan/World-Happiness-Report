# %% [markdown]
# <center> <strong> WORLD HAPPINESS REPORT </strong> </center>

# %% [markdown]
# Click <a href="https://www.kaggle.com/unsdsn/world-happiness"> here</a> to see the dataset!

# %%
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd
import seaborn as sns

# %%
df = []
for i in range(2015, 2020, 1):
    df_i = pd.read_csv(f"datasets/{i}.csv")
    df.append(df_i)

# %% [markdown]
# * Data Analysis in 2015 & 2016

# %%
data_2015, data_2016 = df[0], df[1]

# %%
print(f"2015 -> {data_2015.shape}\n2016 -> {data_2016.shape}")
# Out:
# 2015 -> (158, 12)
# 2016 -> (157, 13)

# %%
data_2015.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
list(data_2015.columns)
# Out:
# ['Country',
#  'Region',
#  'Happiness Rank',
#  'Happiness Score',
#  'Standard Error',
#  'Economy (GDP per Capita)',
#  'Family',
#  'Health (Life Expectancy)',
#  'Freedom',
#  'Trust (Government Corruption)',
#  'Generosity',
#  'Dystopia Residual']

# %%
data_2015.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %%
data_2015.describe().T
# Out:
#                                count       mean        std      min  \
# Happiness Rank                 158.0  79.493671  45.754363  1.00000
# Happiness Score                158.0   5.375734   1.145010  2.83900
# Standard Error                 158.0   0.047885   0.017146  0.01848
# Economy (GDP per Capita)       158.0   0.846137   0.403121  0.00000
# Family                         158.0   0.991046   0.272369  0.00000
# Health (Life Expectancy)       158.0   0.630259   0.247078  0.00000
# Freedom                        158.0   0.428615   0.150693  0.00000
# Trust (Government Corruption)  158.0   0.143422   0.120034  0.00000
# Generosity                     158.0   0.237296   0.126685  0.00000
# Dystopia Residual              158.0   2.098977   0.553550  0.32858
#
#                                      25%        50%         75%        max
# Happiness Rank                 40.250000  79.500000  118.750000  158.00000
# ...

# %%
list(data_2016.columns)
# Out:
# ['Country',
#  'Region',
#  'Happiness Rank',
#  'Happiness Score',
#  'Lower Confidence Interval',
#  'Upper Confidence Interval',
#  'Economy (GDP per Capita)',
#  'Family',
#  'Health (Life Expectancy)',
#  'Freedom',
#  'Trust (Government Corruption)',
#  'Generosity',
#  'Dystopia Residual']

# %%
data_2015.rename(columns= {'Happiness Score': 'happiness_score'}, inplace=True)
data_2016.rename(columns= {'Happiness Score': 'happiness_score'}, inplace=True)

data_2015.rename(columns= {'Happiness Rank': 'happiness_rank'}, inplace=True)
data_2016.rename(columns= {'Happiness Rank': 'happiness_rank'}, inplace=True)

# %% [markdown]
# * Data Cleaning

# %%
print("Data in 2015: " ,data_2015.isna().sum().unique())
print("Data in 2016: ", data_2016.isna().sum().unique())
# Out:
# Data in 2015:  [0]
# Data in 2016:  [0]

# %% [markdown]
# Good, there aren't any missing values!

# %%
print("Duplicated values of data in 2015: ", data_2015.duplicated().sum())
print("Duplicated values of data in 2016: ", data_2016.duplicated().sum())
# Out:
# Duplicated values of data in 2015:  0
# Duplicated values of data in 2016:  0

# %% [markdown]
# Neither are duplicated values!

# %% [markdown]
# * Visualization

# %%
sns.pairplot(data=data_2015, hue='happiness_rank')

# %% [markdown]
# Correlation between features

# %%
sns.heatmap(data_2015.corr(), annot=True)
# Out:
# C:\Users\Salih Furkan\AppData\Local\Temp\ipykernel_13224\1184065608.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data_2015.corr(), annot=True)
# <AxesSubplot: >

# %% [markdown]
# Observations:
# - As economy increases,health (life expectancy) increases
# - Standard error is not necessarily correlated with any feature, so it can be removed
# - Economy has a clear impact on family
# - Freedom affects the happiness score

# %%
data_2015.rename(columns={"Standard Error": "standard_err"}, inplace=True)

# %%
data_2015.drop(columns="standard_err", inplace=True)

# %%
sns.heatmap(data_2016.corr(), annot=True)
# Out:
# C:\Users\Salih Furkan\AppData\Local\Temp\ipykernel_13224\1090901620.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data_2016.corr(), annot=True)
# <AxesSubplot: >

# %%
plt.figure(figsize=(15,6))
plt.subplot(121)
plt.scatter(data=data_2015, x='happiness_score', y='Freedom', marker='o')
plt.title('Relationship between the happiness score and freedom in 2015')
plt.xlabel('Happiness Score')
plt.ylabel('Freedom')


plt.subplot(122)
plt.scatter(data=data_2016, x='happiness_score', y='Freedom', marker='o')
plt.title('Relationship between the happiness score and freedom in 2016')
plt.xlabel('Happiness Score')
plt.ylabel('Freedom')
# Out:
# Text(0, 0.5, 'Freedom')

# %% [markdown]
# Storing some important data to compare 2015 with 2016
#
# To check the economy column, it has to be renamed first.

# %%
data_2015.rename(columns={"Economy (GDP per Capita)": "economy"}, inplace=True)
data_2016.rename(columns={"Economy (GDP per Capita)": "economy"}, inplace=True)

# %%
total_2015_data = [data_2015.happiness_score.sum(),data_2015.Freedom.sum(), data_2015.economy.sum()]
total_2016_data = [data_2016.happiness_score.sum(),data_2016.Freedom.sum(), data_2016.economy.sum()]

# %%
print("The difference between happiness scores between 2015 and 2016 =", format(total_2015_data[0]-total_2016_data[0]))
print("The difference between freedom scores between 2015 and 2016 =", format(total_2015_data[1]-total_2016_data[1]))
print("The difference between economy per gapita between 2015 and 2016 =", format(total_2015_data[2]-total_2016_data[2]))
# Out:
# The difference between happiness scores between 2015 and 2016 = 4.362999999999943
# The difference between freedom scores between 2015 and 2016 = 9.47511999999999
# The difference between economy per gapita between 2015 and 2016 = -16.06944999999999

# %% [markdown]
# - Country-based happiness score comparasion

# %%
len(data_2016.Country) == len(data_2015.Country)
# Out:
# False

# %%
for i in data_2015.Country:
    print("Country:", i, " | Happiness score: ", data_2015["happiness_score"][data_2015.Country == i].sort_values())
# Out:
# Country: Switzerland  | Happiness score:  0    7.587
# Name: happiness_score, dtype: float64
# Country: Iceland  | Happiness score:  1    7.561
# Name: happiness_score, dtype: float64
# Country: Denmark  | Happiness score:  2    7.527
# Name: happiness_score, dtype: float64
# Country: Norway  | Happiness score:  3    7.522
# Name: happiness_score, dtype: float64
# Country: Canada  | Happiness score:  4    7.427
# Name: happiness_score, dtype: float64
# Country: Finland  | Happiness score:  5    7.406
# Name: happiness_score, dtype: float64
# Country: Netherlands  | Happiness score:  6    7.378
# Name: happiness_score, dtype: float64
# Country: Sweden  | Happiness score:  7    7.364
# Name: happiness_score, dtype: float64
# Country: New Zealand  | Happiness score:  8    7.286
# Name: happiness_score, dtype: float64
# Country: Australia  | Happiness score:  9    7.284
# Name: happiness_score, dtype: float64
# Country: Israel  | Happiness score:  10    7.278
# ...

# %%
for i in data_2016.Country:
    print("Country:", i, " | Happiness score: ", data_2016["happiness_score"][data_2016.Country == i].sort_values())
# Out:
# Country: Denmark  | Happiness score:  0    7.526
# Name: happiness_score, dtype: float64
# Country: Switzerland  | Happiness score:  1    7.509
# Name: happiness_score, dtype: float64
# Country: Iceland  | Happiness score:  2    7.501
# Name: happiness_score, dtype: float64
# Country: Norway  | Happiness score:  3    7.498
# Name: happiness_score, dtype: float64
# Country: Finland  | Happiness score:  4    7.413
# Name: happiness_score, dtype: float64
# Country: Canada  | Happiness score:  5    7.404
# Name: happiness_score, dtype: float64
# Country: Netherlands  | Happiness score:  6    7.339
# Name: happiness_score, dtype: float64
# Country: New Zealand  | Happiness score:  7    7.334
# Name: happiness_score, dtype: float64
# Country: Australia  | Happiness score:  8    7.313
# Name: happiness_score, dtype: float64
# Country: Sweden  | Happiness score:  9    7.291
# Name: happiness_score, dtype: float64
# Country: Israel  | Happiness score:  10    7.267
# ...

# %% [markdown]
# - Building the ML model

# %% [markdown]
# Since the region and country columns are string, they must be converted to numbers to be evaluated by the model

# %%
data_2015["Country"] = data_2015["Country"].astype('category').cat.codes.to_numpy()
data_2015["Region"] = data_2015["Region"].astype('category').cat.codes.to_numpy()

# %%
import models

# %%
models.linear(data_2015)
# Out:
# MSE for linear regression model: 6.994513208483984e-08

# %%
for i in [3,5,20,50,100]:
    models.knn(data_2015, n_neighbors=i)
# Out:
# MSE for KNN :  0.0461178611111111
# MSE for KNN :  0.053396854999999986
# MSE for KNN :  0.14118466818749997
# MSE for KNN :  0.39464627096000016
# MSE for KNN :  0.9754876183874999

# %% [markdown]
# It seems that setting n_neighbors to 3 gives the best accuracy. Let's now test for the leaf size

# %%
for i in[10,30,60,100,200]:
    models.knn(data_2015, n_neighbors=3, leaf_size=i)
    pass
# Out:
# MSE for KNN :  0.0461178611111111
# MSE for KNN :  0.0461178611111111
# MSE for KNN :  0.0461178611111111
# MSE for KNN :  0.0461178611111111
# MSE for KNN :  0.0461178611111111

# %% [markdown]
# Well, it did not affect anything.

# %% [markdown]
# When applying the same steps foor Gradient Boosting Regressor, it gave the best accuracy with the learning rate of 0.1, max depth of 3 and n_estimators of 100
#
# Let's use them!

# %%
models.gradient_boosting(data=data_2015, lr=0.1, max_depth=3, estimators=100)
# Out:
# MSE for Gradient Boosting Regressor:  0.002283909293667375

# %% [markdown]
# ----
# It was determined that gradient boosting regressor is the best option for this dataset. In this project, only 2015 and 2016 were analyzed. Using the same techniques, it can be applied for other years as well.
